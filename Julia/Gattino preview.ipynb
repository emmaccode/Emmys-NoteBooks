# %%
using Pkg; Pkg.activate(".")
# Out:
#   Activating project at `~/dev/packages/Prrty.jl`

# %%
Pkg.resolve()
# Out:
#   No Changes to `~/dev/packages/Prrty.jl/Project.toml`
#   No Changes to `~/dev/packages/Prrty.jl/Manifest.toml`

# %%
using Gattino
# Out:
# [ Info: Precompiling Gattino [f0fb3ee5-f608-41f3-a42d-dac276373afc]

# %%
Pkg.status()
# Out:
# Project Gattino v0.1.0
# Status `~/dev/packages/Prrty.jl/Project.toml`
#   [f9ffe950] Contexts v0.1.0 `https://github.com/ChifiSource/Contexts.jl#Unstable`
# ⌃ [a47e2ad8] Toolips v0.2.3
# ⌃ [1710be6b] ToolipsDefaults v0.1.0
# ⌃ [33f7ff50] ToolipsMarkdown v0.1.1
#   [8ae86ec9] ToolipsSVG v0.1.0 `https://github.com/ChifiSource/ToolipsSVG.jl#Unstable`
# ⌃ [2fe55384] ToolipsSession v0.3.0
# Info Packages marked with ⌃ have new versions available and may be upgradable.

# %%
x = [1, 8, 45, 3, 4, 7]
y = [5, 7, 42, 23, 8, 4]
# Out:
# 6-element Vector{Int64}:
#   5
#   7
#  42
#  23
#   8
#   4

# %%
scatter(x, y)
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=jdbN9iJU y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=katjMdzg y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=BpOsrvH9 y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=T8J96aWg y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=T6S1fTR3 y1=0 x2=126 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=126></line><line id=7c866c3R y1=126 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=126 x1=0></line><line id=vxCjEgjq y1=0 x2=251 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=251></line><line id=iECIqh2y y1=251 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=251 x1=0></line><line id=vRdZN3cp y1=0 x2=3
# ...

# %%
line(x, y)
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=zhvUtGE5 y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=nPbjbiir y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=0Zu8c2Pr y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=RdhM1Jto y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=GOEwKiUC y1=0 x2=126 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=126></line><line id=eNP07kjv y1=126 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=126 x1=0></line><line id=llFvFCGP y1=0 x2=251 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=251></line><line id=4sXYaXVd y1=251 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=251 x1=0></line><line id=atn5pQ6A y1=0 x2=3
# ...

# %%
hist(x, y)
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=LnkRUZlJ y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=CtPf8T8G y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=CaKt494n y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=Hf5YEGw9 y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=tbThmPqN y1=0 x2=84 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=84></line><line id=ZhNw4rlq y1=84 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=84 x1=0></line><line id=XcKllrxG y1=0 x2=167 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=167></line><line id=kcRteLUn y1=167 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=167 x1=0></line><line id=ZzkOuN1n y1=0 x2=250 s
# ...

# %%
x = [5, 10, 15]
y = [5, 10, 15]
# Out:
# 3-element Vector{Int64}:
#   5
#  10
#  15

# %%
hist(x, y)
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=6pHzVw1P y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=cXdE9Xnl y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=nNuNevjb y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=pZLnKOvC y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=fILKuGNh y1=0 x2=168 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=168></line><line id=QjiixiCN y1=168 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=168 x1=0></line><line id=J9Ydvw6F y1=0 x2=335 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=335></line><line id=2c3PQawi y1=335 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=335 x1=0></line><text id=Sc9oEF1N y=490 sty
# ...

# %%
plt = line(x, y)
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=8d9QYnhU y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=84RVqCQY y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=9HqfTZeP y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=LFjyaKCH y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=xyDKmBxw y1=0 x2=126 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=126></line><line id=7b5Wt5iK y1=126 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=126 x1=0></line><line id=mOlKhvzt y1=0 x2=251 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=251></line><line id=bMsExA5Z y1=251 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=251 x1=0></line><line id=7eVhNY6P y1=0 x2=3
# ...

# %%
Gattino.bars!(plt, x, y, "fill" => "lightblue", "stroke-width" => "2", "stroke" => "gray")
# Out:
# Dict{String, UnitRange{Int64}} with 3 entries:
#   "line"     => 2:2
#   "yWNDCjtl" => 3:5
#   "plotbase" => 1:1

# %%
plt
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=8d9QYnhU y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=84RVqCQY y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=9HqfTZeP y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=LFjyaKCH y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=xyDKmBxw y1=0 x2=126 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=126></line><line id=7b5Wt5iK y1=126 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=126 x1=0></line><line id=mOlKhvzt y1=0 x2=251 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=251></line><line id=bMsExA5Z y1=251 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=251 x1=0></line><line id=7eVhNY6P y1=0 x2=3
# ...

# %%
Gattino.points!(plt, x, y)
# Out:
# 3-element Vector{Dict{String, UnitRange{Int64}}}:
#  Dict("enkGKx7d" => 6:6, "line" => 2:2, "JxM3jsXj" => 8:8, "yWNDCjtl" => 3:5, "plotbase" => 1:1, "OIiOFYiX" => 7:7)
#  Dict("enkGKx7d" => 6:6, "line" => 2:2, "JxM3jsXj" => 8:8, "yWNDCjtl" => 3:5, "plotbase" => 1:1, "OIiOFYiX" => 7:7)
#  Dict("enkGKx7d" => 6:6, "line" => 2:2, "JxM3jsXj" => 8:8, "yWNDCjtl" => 3:5, "plotbase" => 1:1, "OIiOFYiX" => 7:7)

# %%
plt
# Out:
# "<svg id=window height=500 width=500><g id=plotbase height=500 width=500><line id=8d9QYnhU y1=500 x2=500 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=84RVqCQY y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=500 x1=0></line><line id=9HqfTZeP y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=1></line><line id=LFjyaKCH y1=1 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=xyDKmBxw y1=0 x2=126 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=126></line><line id=7b5Wt5iK y1=126 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=126 x1=0></line><line id=mOlKhvzt y1=0 x2=251 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=500 x1=251></line><line id=bMsExA5Z y1=251 x2=500 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=251 x1=0></line><line id=7eVhNY6P y1=0 x2=3
# ...

# %%
plt.layers
# Out:
# Dict{String, UnitRange{Int64}} with 6 entries:
#   "enkGKx7d" => 6:6
#   "line"     => 2:2
#   "JxM3jsXj" => 8:8
#   "yWNDCjtl" => 3:5
#   "plotbase" => 1:1
#   "OIiOFYiX" => 7:7

# %%
con = Gattino.Context(500, 500)
# Out:
# "<svg id=window height=500 width=500></svg>"
# "<svg id=window height=500 width=500></svg>"

# %%
Gattino.Contexts.group!(con, "plot1", 250, 250) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
      #  Gattino.bars!(g, x, y, "fill" => "pink", "stroke" => "black", "stroke-width" => "2")
end
Gattino.Contexts.group!(con, "plot2", 250, 250, 250 => 0) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
        Gattino.line!(g, x, y)
end
Gattino.Contexts.group!(con, "plot3", 250, 250, 0 => 250) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
end
Gattino.Contexts.group!(con, "plot4", 250, 250, 250 => 250) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
end
# Out:
# Dict{String, UnitRange{Int64}} with 4 entries:
#   "plot3" => 23:23
#   "plot2" => 22:22
#   "plot1" => 21:21
#   "plot4" => 24:24

# %%
con
# Out:
# "<svg id=window height=500 width=500><g id=plot1 height=250 width=250><line id=xTYHQNJz y1=250 x2=250 style='fill: none;stroke: black;stroke-width: 4;' y2=250 x1=0></line><line id=xNWUKLgF y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=250 x1=0></line><line id=6XnSAXKn y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=1></line><line id=WuubktmP y1=1 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=6PMk7nav y1=0 x2=43 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=43></line><line id=LZisapGp y1=43 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=43 x1=0></line><line id=59iKjkiQ y1=0 x2=85 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=85></line><line id=3wfD0KjM y1=85 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=85 x1=0></line><line id=6eIZK0pG y1=0 x2=127 style='f
# ...

# %%
con = Gattino.Context(500, 250)
# Out:
# "<svg id=window height=250 width=500></svg>"
# "<svg id=window height=250 width=500></svg>"

# %%
Gattino.Contexts.group!(con, "plot1", 250, 250) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
        Gattino.bars!(g, x, y, "fill" => "pink", "stroke" => "black", "stroke-width" => "2")
end
Gattino.Contexts.group!(con, "plot2", 250, 250, 250 => 0) do g
        Gattino.axes!(g)
        Gattino.grid!(g, 6)
        Gattino.gridlabels!(g, x, y)
        Gattino.line!(g, x, y, "stroke" => "orange")
end
# Out:
# Dict{String, UnitRange{Int64}} with 2 entries:
#   "plot2" => 4:4
#   "plot1" => 3:3

# %%
con
# Out:
# "<svg id=window height=250 width=500><g id=plot1 height=250 width=250><line id=BUAN3u3X y1=250 x2=250 style='fill: none;stroke: black;stroke-width: 4;' y2=250 x1=0></line><line id=vzzZ8imL y1=0 x2=0 style='fill: none;stroke: black;stroke-width: 4;' y2=250 x1=0></line><line id=OlYPR9NM y1=0 x2=1 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=1></line><line id=zAQs5s0M y1=1 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=1 x1=0></line><line id=yrYY4vAL y1=0 x2=43 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=43></line><line id=MsUJ6HI9 y1=43 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=43 x1=0></line><line id=ujjPG0H5 y1=0 x2=85 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=250 x1=85></line><line id=XEInpHAx y1=85 x2=250 style='fill: none;stroke: lightblue;stroke-width: 1;opacity: 80%;' y2=85 x1=0></line><line id=pWPOJg7w y1=0 x2=127 style='f
# ...

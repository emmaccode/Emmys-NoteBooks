# %% [markdown]
# #### comparison and overview

# %%
module Example

abstract type SuperType <: Any end
                      # ^ (this is also implicit, doesn't need to be typed)
mutable struct Type <: SuperType
    field::Int64
   # ^ field  ^ field type
     function SuperType()
            # ^ inner constructor
           # v call to `new`, providing our fields
           new(0)
     end
end

function sample_function(sample_argument::Type)

end

# exports
export sample_function
end
# Out:
# WARNING: replacing module Example.
# Main.Example

# %%
mutable struct File{T <: Any}
    uri::Vector{SubString}
    name::String
    function File(uri::String)
        splits = split(uri, "/")
        file_extension = split(splits[length(splits)], ".")
        file_extension = Symbol(file_extension[2:length(file_extension)])
        new{file_extension}(splits, length(splits))::File{T}
    end
end

function turn_into_document(file::File{:doc})

end

function turn_into_document(file::File{:docx})
    
end
# Out:
# turn_into_document (generic function with 2 methods)

# %% [markdown]
# ```python
# class File:
#     def __init__(self, uri):
#         self.uri = uri.split("/")
#         self.name = self.uri[len(self.uri)]
#
# class DocFile(File):
#     def turn_into_document(self):
#         pass
#
# class DocXFile(File):
#     def turn_into_document(self):
#         pass
# ```

# %% [markdown]
# #### key differences between python and julia

# %% [markdown]
# ```python
# class Vehicle:
#     def __init__(self, model, horsepower, weight, distance, time):
#         self.model = model
#         self.distance = distance
#         self.hp = horsepower
#         self.time = time
#     def get_speed():
#         self.distance / self.time
#
# class Car(Vehicle):
#     pass
# # both __init__ and get_speed are inherited.
# class Truck(Vehicle):
#     def __init__(self, model, horsepower, weight, distance, time, truck_class, capacity):
#         self.model = model
#         self.distance = distance
#         self.hp = horsepower
#         self.time = time
#         self.truck_class = truck_class
#         self.capacity = capacity
#     # get_speed is inherited, __init__ is `overloaded`
# ```

# %%
abstract type AbstractData end

struct EnumeratedData <: AbstractData
    number::Int64
    data::String
end

struct LabeledData <: AbstractData
    name::String
    data::String
end

function show_data(t::AbstractData)
    print(join(data * "\n" for data in split(t.data, ";")))
end
# Out:
# show_data (generic function with 1 method)

# %%
methods(show_data)
# Out:
# # 1 method for generic function "show_data" from Main:
#  [1] show_data(t::AbstractData)
#      @ In[59]:13

# %%
function no_methods end
methods(no_methods)
# Out:
# # 0 methods for generic function "no_methods" from Main

# %%
struct ExampleType
   field::Int64
end

# %%
mutable struct MutableExampleType
    field::Int64
end

# %%
mutable struct MutableExampleTypeWithImmutableField
    const field::Int64
end

# %%
mutable struct Constructor
    # fields
   id::Int64
   name::String
     # v inner constructor
   function Constructor(name::String)
      # v inner constructor = use `new`
       new(rand(1:20), name)::Constructor
   end
end # - Constructor

# outer constructor:
Constructor() = Constructor("Unnamed")
# Out:
# Constructor

# %%
abstract type Vehicle end

# %%
abstract type Car <: Vehicle end

mutable struct Civic <: Car
    year::Int64
    value::Float64
end

# %%
car = Civic(2003, 2023.27)

println(Car <: Vehicle)
println(Civic <: Car)
println(Civic <: Vehicle)
println(typeof(car) <: Car && Car <: Vehicle)
println(Vehicle <: Car)
# Out:
# true
# true
# true
# true
# false

# %%
myvec = [5, 10, 15, 20]

println(typeof(myvec))
# Out:
# Vector{Int64}

# %%
function type_of_vec(vec::Vector{<:Any})
    println("a type we haven't made a function for, $(typeof(vec))")
end

function type_of_vec(vec::Vector{<:Number})
    println("some kind of numerical vector")
end

function type_of_vec(vec::Vector{Int64})
  println("this is a Vector of numbers")
end

function type_of_vec(vec::Vector{<:AbstractString})
    println("a vector of strings")
end
# Out:
# type_of_vec (generic function with 4 methods)

# %%
display(typeof(myvec))
# Out:
# Vector{Int64} (alias for Array{Int64, 1})

# %%
# parameter T and N vv
mutable struct MyArray{T <: Any, N}
    dims::Vector{T}   #^
       #  ^^ of type Vector{T}
   
              #     vv providing parameters
    function MyArray{T, N}(dims::T ...) where {T <: Any, N <: Any}
        new{T, N}(Vector{T}([dim for dim in dims]))
    end
end

# %%
new_mat = [1 4 7; 2 5 8; 3 6 9]
# Out:
# 3×3 Matrix{Int64}:
#  1  4  7
#  2  5  8
#  3  6  9

# %%
const MyVector{T} = MyArray{T, 1}
# Out:
# MyVector (alias for MyArray{T, 1} where T)

# %%
function infinite_values(x::Int64 ...)
     # x is a tuple
    println(x)
    allocated = [x ...]
    # ^ converting x to an allocated `Vector`
end

infinite_values(10, 11, 22, 33)

(10, 11, 22, 33)
# Out:
# (10, 11, 22, 33)
# (10, 11, 22, 33)

# %%
example() = begin # <- the begin is only necessary for multi-line

end
# Out:
# example (generic function with 1 method)

# %%
mean(x::Vector{<:Number}) = sum(x) / len(x)
# Out:
# mean (generic function with 1 method)

# %%
# v argument
new_function = x::Int64 -> x += 5

multi_line_andarg = (x::Int64, y::Float64) -> begin
     x += y
     x * y
end
# Out:
# #31 (generic function with 1 method)

# %%
myvec = [5, 6, 11, 12]

# `filter!` will remove values according to our conditional response.
filter!(myvec) do value::Int64
    value < 11
end

println(myvec)
# Out:
# [5, 6]

# %%
myvec = [5, 6, 11, 12]
x = filter(myvec) do value::Int64
    value < 11
end

println(myvec)
println(x)
# Out:
# [5, 6, 11, 12]
# [5, 6]

# %% [markdown]
# ```python
# new_dict = {"key" : "value", "key" : "value"}
# ```

# %%
pair = :A => 1
# Out:
# :A => 1

# %%
my_dict = Dict(:A => [1, 2, 3], :B => [1, 2, 3])
# Out:
# Dict{Symbol, Vector{Int64}} with 2 entries:
#   :A => [1, 2, 3]
#   :B => [1, 2, 3]

# %%
push!(my_dict, :C => [4, 5, 6])
for pair in my_dict
    println(pair)
    println("key: $(pair[1])")
    println("value: $(pair[2])")
end
# Out:
# :A => [1, 2, 3]
# key: A
# value: [1, 2, 3]
# :B => [1, 2, 3]
# key: B
# value: [1, 2, 3]
# :C => [4, 5, 6]
# key: C
# value: [4, 5, 6]

# %%
import Base: getindex, setindex!

mutable struct Person
    name::String
end

function getindex(vector_of_person::Vector{Person}, name::String)
    first_found = findfirst(person::Person -> person.name == name, vector_of_person)
    if isnothing(first_found)
        throw(BoundsError())
    end
    vector_of_person[first_found]
end

function setindex!(vector_of_person::Vector{Person}, new_name::String, name::String)
    first_found = findfirst(person::Person -> person.name == name, vector_of_person)
    if isnothing(first_found)
        throw(BoundsError())
    end
    vector_of_person[first_found].name = new_name
end

p = Person("Emma")
p2 = Person("Oliver")

vec = [p, p2]

println(vec["Emma"])

vec["Oliver"] = "Thomas"

println(vec)
# Out:
# Person("Emma")
# Person[Person("Emma"), Person("Thomas")]

# %%
vec = Vector{Int64}()
push!(vec, 1, 2)

append!(vec, [3, 4, 5])
# Out:
# 5-element Vector{Int64}:
#  1
#  2
#  3
#  4
#  5

# %%
push!(vec, [1 , 1, 8])
# Out:
# MethodError: Cannot `convert` an object of type Vector{Int64} to an object of type Int64
#
# Closest candidates are:
#   convert(::Type{T}, ::Base.TwicePrecision) where T<:Number
#    @ Base twiceprecision.jl:273
#   convert(::Type{T}, ::AbstractChar) where T<:Number
#    @ Base char.jl:185
#   convert(::Type{T}, ::CartesianIndex{1}) where T<:Number
#    @ Base multidimensional.jl:127
#   ...
#
#
# Stacktrace:
#  [1] push!(a::Vector{Int64}, item::Vector{Int64})
#    @ Base ./array.jl:1060
#  [2] top-level scope
#    @ In[86]:1

# %%
vec = Vector(1:5)
insert!(vec, 3, 100)
# Out:
# 6-element Vector{Int64}:
#    1
#    2
#  100
#    3
#    4
#    5

# %%
vcat([5, 10, 15], [-5, -10, -15])
# Out:
# 6-element Vector{Int64}:
#    5
#   10
#   15
#   -5
#  -10
#  -15

# %%
hcat([-5, -10, -15], [5, 10, 15])
# Out:
# 3×2 Matrix{Int64}:
#   -5   5
#  -10  10
#  -15  15

# %%
data = Dict{String, String}("Al" => "127.0.0.1", "John" => "127.0.0.8")

more_data = Dict{String, String}("Hank" => "192.168.0.1")

merged = merge(more_data, data)
# Out:
# Dict{String, String} with 3 entries:
#   "Al"   => "127.0.0.1"
#   "John" => "127.0.0.8"
#   "Hank" => "192.168.0.1"

# %%
using Statistics

numbers = [rand(1:1000) for x in 1:1000]
function normalize(x::Number, mu::Number, std::Number)
    (x - mu) / std
end

println(broadcast(normalize, numbers, length(numbers) / sum(numbers), Statistics.std(numbers)))
# Out:
# [0.8386780448071021, 1.7252877141243237, 2.7933271613327144, 2.2832698612235793, 2.4989316726791198, 2.115532896758159, 0.05818767953943194, 1.9272567121541158, 2.8857536519565175, 2.961064125798135, 0.5682449796485672, 0.2841191010642838, 0.7667907743219219, 3.1253778869071183, 0.20538542386622938, 0.4313168453910812, 2.4236211988375023, 1.3145033113518658, 1.9683351524313615, 2.759095127768343, 1.1159575166785112, 2.5639725364514256, 1.8279838148174383, 2.827559194897086, 0.8044460112427305, 0.9002957052229706, 1.4480082422529146, 1.95806554236205, 2.7864807546198405, 0.10268932317311488, 0.5237433360148842, 0.2293478473612894, 1.5815131731539633, 0.7325587407575503, 3.234920394313107, 0.030802052687934744, 1.2665784643617457, 1.4171994120449802, 1.0509166529062053, 2.1908433705997763, 1.1673055670250683, 0.3320439480544039, 3.0500674130655008, 1.0783022797577024, 1.4000833952627945, 2.697477467352474, 1.2220768207280628, 2.372273148490945, 0.32862074469796676, 1.6123220033618977, 3.0740298365605607, 1.4377386321836032, 3.3923877487092158, 1.3453121415598002, 1.2802712777874943, 1.1193807200349484, 1.32134971806474, 3.3615789185012814, 1.24946244757956, 0.08899650974736628, 3.306807664798287, 2.7933271613327144, 0.5990538098565016, 1.5370115295202804, 0.40735442189602117, 2.789903957976277, 2.3140786914315137, 1.5370115295202804, 2.1052632866888477, 0.9482205522130908, 2.132648913540345, 2.02995281284723, 2.2216522008077106, 2.2216522008077106, 2.830982398253523, 0.1232285433117378, 2.1976897773126507, 0.1232285433117378, 3.275998834590353, 2.779634347906966, 0.0684572896087434, 2.1566113370354048, 3.121954683550681, 1.5780899697975264, 3.3102308681547243, 1.1741519737379427, 3.354732511788407, 0.45185606552970414, 1.32134971806474, 1.8519462383124985, 1.160459160312194, 2.854944821748583, 1.5609739530153406, 0.2567334742127866, 1.1091111099656368, 0.6675178769852446, 1.5883595798668377, 2.4065051820553167, 2.413351588768191, 0.5340129460841957, 0.24646386414347515, 2.7693647378376545, 2.7693647378376545, 0.26700308428209807, 1.2357696341538114, 2.211382590738399, 2.136072116896782, 1.9717583557877987, 1.5130491060252205, 0.56482177629213, 0.08557330639092914, 1.7629429510451327, 1.0269542294111453, 2.9713337358674465, 1.0509166529062053, 0.9139885186487193, 0.8112924179556048, 1.1467663468864455, 2.9028696687387034, 0.23277105071772655, 3.2691524278774784, 2.64270621364948, 1.5370115295202804, 2.3517339283523224, 2.7317095009168457, 0.150614170163235, 2.3483107249958852, 1.7047484939857007, 2.2661538444413933, 1.5849363765104005, 0.4826648957376385, 2.6153205867979827, 0.7188659273318018, 0.3457367614801525, 2.7830575512634033, 2.5434333163128025, 3.3650021218577186, 3.0740298365605607, 2.3893891652731307, 3.1561867171150526, 1.157035956955757, 0.9892989924903366, 3.104838666768495, 3.039797802996189, 1.454854648965789, 3.1664563271843638, 0.3388903547672782, 2.293539471292891, 1.547281139589592, 2.1292257101839076, 0.3731223883316497, 3.0055657694318176, 2.3483107249958852, 1.7560965443322583, 0.955066958925965, 1.2836944811439315, 0.4381632521039555, 1.4651242590351004, 1.7800589678273182, 3.186995547322987, 1.047493449549768, 0.7736371810347962, 0.3594295749059011, 2.5468565196692396, 0.6161698266386872, 1.526741919450969, 2.0573384396987273, 2.372273148490945, 3.3444629017190954, 0.5785145897178786, 1.3829673784806087, 1.841676628243187, 0.6024770132129387, 1.9169871020848044, 2.7043238740653486, 0.01026283254931185, 3.2041115641051725, 2.923408888877326, 2.207959387381962, 1.7492501376193839, 2.05391523634229, 0.21907823729197798, 2.2832698612235793, 2.050492032985853, 1.1741519737379427, 1.0338006361240195, 1.8040213913223784, 0.814715621312042, 0.4895113024505128, 0.8078692145991677, 1.9443727289363015, 2.368849945134508, 2.0094135927086074, 2.872060838530769, 3.3341932916497843, 1.6054755966490235, 1.5438579362331548, 2.026529609490793, 0.5442825561535072, 0.4997809125198242, 2.933678498946638, 1.1399199401735711, 2 ...

# %%
sample_vec = [1, 2, 3, 4, 5]

println(findall(x -> x < 3, sample_vec))
# Out:
# [1, 2]

# %%
source_string = "Julia is awesome!"

println(findfirst("awesome", source_string))
# Out:
# 10:16

# %%
if contains(source_string, "Julia")
    println("Julia is indeed awesome")
end
# Out:
# Julia is indeed awesome

# %%
source_string = replace(source_string, "is" => "really is very")
# Out:
# "Julia really is very awesome!"

# %%
words = split(source_string, " ")
# Out:
# 5-element Vector{SubString{String}}:
#  "Julia"
#  "really"
#  "is"
#  "very"
#  "awesome!"

# %%
sentence = join(words, " ")
# Out:
# "Julia really is very awesome!"

# %%
phrase_end = findfirst("is ", sentence)
sentence = sentence[1:maximum(phrase_end)] * "a great language!"
# Out:
# "Julia really is a great language!"

# %%
sample_dct = Dict(:A => [1, 2, 3], :B => [1, 2, 3])
sample_arr = [5, 1, 3, 8, 4]

println(sample_dct)
delete!(sample_dct, :A)
println(sample_dct)

println(sample_arr)
deleteat!(sample_arr, 1)
println(sample_arr)
# Out:
# Dict(:A => [1, 2, 3], :B => [1, 2, 3])
# Dict(:B => [1, 2, 3])
# [5, 1, 3, 8, 4]
# [1, 3, 8, 4]

# %%
filter(pair -> pair[1] == :B, sample_dct)
# Out:
# Dict{Symbol, Vector{Int64}} with 1 entry:
#   :B => [1, 2, 3]

# %%
filter(x -> x < 20 && x > 1, [5, 10, 2, 4, 6, 3, 7, 25, 65, 22, 33, 14, 22, 11, 4, 6, 32])
# Out:
# 11-element Vector{Int64}:
#   5
#  10
#   2
#   4
#   6
#   3
#   7
#  14
#  11
#   4
#   6

# %% [markdown]
# #### dataframes

# %%
using DataFrames

# %%
df = DataFrame(:age => [52, 22, 17, 28], :color => ["red", "orange", "blue", missing], 
    :height => [5, 8, 9, 2], :depth => [5.2, missing, 6.6, 3.2])
# Out:
# 4×4 DataFrame
#  Row │ age    color    height  depth
#      │ Int64  String?  Int64   Float64?
# ─────┼───────────────────────────────────
#    1 │    52  red           5        5.2
#    2 │    22  orange        8  missing
#    3 │    17  blue          9        6.6
#    4 │    28  missing       2        3.2

# %%
dropmissing!(df)
# Out:
# 2×4 DataFrame
#  Row │ age    color   height  depth
#      │ Int64  String  Int64   Float64
# ─────┼────────────────────────────────
#    1 │    52  red          5      5.2
#    2 │    17  blue         9      6.6

# %%
copy = filter(row -> row[:color] == "red", df)
# Out:
# 1×4 DataFrame
#  Row │ age    color   height  depth
#      │ Int64  String  Int64   Float64
# ─────┼────────────────────────────────
#    1 │    52  red          5      5.2

# %%
indexed = df[1, 1]
# Out:
# 52

# %%
df[!, Not(:height)]
# Out:
# 2×3 DataFrame
#  Row │ age    color   depth
#      │ Int64  String  Float64
# ─────┼────────────────────────
#    1 │    52  red         5.2
#    2 │    17  blue        6.6

# %%
# using CSV; df = CSV.read("data/sample.csv", DataFrame)

# %%
module APIServer
using Toolips

main = route("/") do c::Connection
    write!(c, "response")
end

export start!, main
end

using Toolips
# Out:
# WARNING: using Toolips.File in module Main conflicts with an existing identifier.

# %%
using Main.APIServer; start!(APIServer, "127.0.0.1":8000)
# Out:
# 🌷 toolips> loaded router type: Vector{Toolips.Route{Connection}}
# 🌷 toolips> server listening at http://127.0.0.1:8000
#       Active manifest files: 7 found
#       Active artifact files: 8 found
#       Active scratchspaces: 5 found
#      Deleted no artifacts, repos, packages or scratchspaces
# [ Info: Listening on: 127.0.0.1:8000, thread id: 1
#    pid              process type                  name active
#   –––– ––––––––––––––––––––––––– ––––––––––––––––––––– ––––––
#   1371 ParametricProcesses.Async Main.APIServer router   true

# %%
pkgversion(Toolips)
# Out:
# v"0.3.3"

# %%
response = get("http://127.0.0.1:8000")
# Out:
# "response"

# %%
kill!(APIServer)
# Out:
# [ Info: Server on 127.0.0.1:8000 closing
#       Active manifest files: 7 found
#       Active artifact files: 8 found
#       Active scratchspaces: 5 found
#      Deleted no artifacts, repos, packages or scratchspaces

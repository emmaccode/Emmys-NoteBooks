# %%
using CairoMakie

# %%
points = [Point2f0(cos(t), sin(t)) for t in LinRange(0, 2pi, 20)]
colors = 1:20
figure, axis, scatterobject = scatter(points, color = colors, markersize = 15)
figure
# Out:
# Figure()

# %%
scatterobject.markersize = 50
# Out:
# 50

# %%
figure
# Out:
# Figure()

# %%
circlefunc = ts -> 1.5 .* Point2f0.(cos.(ts), sin.(ts))
scatter!(circlefunc, LinRange(0, 2pi, 30), color = :red)
figure
# Out:
# Figure()

# %%
fig = Figure(resolution = (700, 500), backgroundcolor = RGBf0(0.98, 0.98, 0.98))
# Out:
# Figure()

# %%
ax1 = fig[1, 1] = Axis(fig, title = "Pre Treatment")
# Out:
# Axis with 0 plots:

# %%
data1 = randn(50, 2) * [1 2.5; 2.5 1] .+ [10 10]

line1 = lines!(ax1, 5..15, x -> x, color = :red, linewidth = 2)
scat1 = scatter!(ax1, data1,
    color = (:red, 0.3), markersize = 15px, marker = '■')

fig
# Out:
# Figure()

# %%
fig.layout
# Out:
# GridLayout[1, 1] with 1 children
#  ┗━ [1, 1] Axis

# %%
ax2, line2 = lines(fig[1, 2], 7..17, x -> -x + 26,
    color = :blue, linewidth = 4,
    axis = (title = "Post Treatment",))

fig
# Out:
# Figure()

# %%
using AbstractPlotting.Colors

figure, ax, lineplot = lines(0..10, sin; linewidth=10)

# animation settings
n_frames = 30
framerate = 30
hue_iterator = LinRange(0, 360, n_frames)

record(figure, "color_animation.mp4", hue_iterator; framerate = framerate) do hue
    lineplot.color = HSV(hue, 1, 0.75)
end
# Out:
# libGL error: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri)
# libGL error: failed to load driver: iris
# libGL error: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri)
# libGL error: failed to load driver: iris
# libGL error: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri)
# libGL error: failed to load driver: swrast
# ┌ Warning:     GLFW couldn't create an OpenGL window.
# │     This likely means, you don't have an OpenGL capable Graphic Card,
# │     or you don't have an OpenGL 3.3 capable video driver installed.
# │     Have a look at the troubleshooting section in the GLMakie readme:
# │     https://github.com/JuliaPlots/GLMakie.jl#troubleshooting-opengl.
# └ @ GLMakie /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:324
# GLFWError (VERSION_UNAVAILABLE): GLX: Failed to create context: GLXBadFBConfig
#
# Stacktrace:
#  [1] _ErrorCallbackWrapper(::Int32, ::Cstring) at /home/emmett/.julia/packages/GLFW/BWxfF/src/callback.jl:43
#  [2] CreateWindow(::Int64, ::Int64, ::String, ::GLFW.Monitor, ::GLFW.Window) at /home/emmett/.julia/packages/GLFW/BWxfF/src/glfw3.jl:499
#  [3] GLFW.Window(; name::String, resolution::Tuple{Int64,Int64}, debugging::Bool, major::Int64, minor::Int64, windowhints::Array{Tuple{UInt32,Integer},1}, contexthints::Array{Tuple{UInt32,Integer},1}, visible::Bool, focus::Bool, fullscreen::Bool, monitor::Nothing, share::GLFW.Window) at /home/emmett/.julia/packages/GLFW/BWxfF/src/glfw3.jl:344
#  [4] GLMakie.Screen(; resolution::Tuple{Int64,Int64}, visible::Bool, title::String, kw_args::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:316
#  [5] Screen at /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:289 [inlined]
#  [6] global_gl_screen at /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:235 [inlined]
#  [7] global_gl_screen(::Tuple{Int64,Int64}, ::Bool, ::Int64) at /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:381
#  [8] global_gl_screen at /home/emmett/.julia/packages/GLMakie/AHGzN/src/screen.jl:380 [inlined]
#  [9] backend_display at /home/emmett/.julia/packages/GLMakie/AHGzN/src/display.jl:2 [inlined]
#  [10] VideoStream(::Scene; framerate::Int64) at /home/emmett/.julia/packages/AbstractPlotting/gE7AT/src/display.jl:347
#  [11] #VideoStream#796 at /home/emmett/.julia/packages/AbstractPlotting/gE7AT/src/display.jl:360 [inlined]
#  [12] Record(::var"#9#10", ::Figure, ::LinRange{Float64}; framerate::Int64) at /home/emmett/.julia/packages/AbstractPlotting/gE7AT/src/display.jl:588
#  [13] #record#802 at /home/emmett/.julia/packages/AbstractPlotting/gE7AT/src/display.jl:583 [inlined]
#  [14] top-level scope at In[12]:10
#  [15] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
